# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import math

# %%
# divide conquer frequency accuracy at a given snr
# changed m = samples at each subsampling phase
# N=1024 possible freq, m=30 (logn) samples at each subsampling (starting at random each time), 6 layers

plt.plot(np.load('../data/divide_conquer/snrs_1024shift.npy'), np.load('../data/divide_conquer/snr_acc_binary_1024shift.npy'), '--bo', label='top/bottom detection')
plt.plot(np.load('../data/divide_conquer/snrs_1024shift.npy'), np.load('../data/divide_conquer/snr_acc_frequency_1024shift.npy'), '--ro', label='frequency detection')
plt.xlabel('snr db', fontsize=18)
plt.ylabel('testing accuracy', fontsize=18)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# divide conquer frequency accuracy at a given snr
# changed m = samples at each subsampling phase
# N=1024 possible freq, m=10 (logn) samples at each subsampling (starting at 0), 6 layers

plt.plot(np.load('../data/divide_conquer/snrs_1024.npy'), np.load('../data/divide_conquer/snr_acc_binary_1024.npy'), '--bo', label='top/bottom detection')
plt.plot(np.load('../data/divide_conquer/snrs_1024.npy'), np.load('../data/divide_conquer/snr_acc_frequency_1024.npy'), '--ro', label='frequency detection')
plt.xlabel('snr db', fontsize=18)
plt.ylabel('testing accuracy', fontsize=18)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# divide conquer frequency accuracy at a given snr
# changed m = samples at each subsampling phase
# N=1024 possible freq, m=30 (3logn) samples at each subsampling (starting at 0), 6 layers

plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_binary.npy'), '--bo', label='top/bottom detection')
plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_frequency.npy'), '--ro', label='frequency detection')
plt.xlabel('snr db', fontsize=18)
plt.ylabel('testing accuracy', fontsize=18)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# divide conquer frequency accuracy at a given snr
# changed m = samples at each subsampling phase
# N=8192 possible freq, m=40 (3logn) samples at each subsampling (starting at 0), 6 layers

plt.plot(np.load('../data/divide_conquer/snrs_8192.npy'), np.load('../data/divide_conquer/snr_acc_binary_8192.npy'), '--bo', label='top/bottom detection')
plt.plot(np.load('../data/divide_conquer/snrs_8192.npy'), np.load('../data/divide_conquer/snr_acc_frequency_8192.npy'), '--ro', label='frequency detection')
plt.xlabel('snr db', fontsize=18)
plt.ylabel('testing accuracy', fontsize=18)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# divide conquer frequency accuracy at a given snr
# changed m = samples at each subsampling phase
# N=16384 possible freq, m=42 (3logn) samples at each subsampling (starting at 0), 6 layers

plt.plot(np.load('../data/divide_conquer/snrs_16384.npy'), np.load('../data/divide_conquer/snr_acc_binary_16384.npy'), '--bo', label='top/bottom detection')
plt.plot(np.load('../data/divide_conquer/snrs_16384.npy'), np.load('../data/divide_conquer/snr_acc_frequency_16834.npy'), '--ro', label='frequency detection')
plt.xlabel('snr db', fontsize=18)
plt.ylabel('testing accuracy', fontsize=18)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# Results
# - Had some training issues last time -> correct training now
# - Accuracy doesn't really change with number of possible frequencies
# - Works better for nn to not use random shifting
# - Same accuracy for boundary vs non boundary frequencies

# %%
# binary detection accuracy for diff total number of frequencies
# layers=6, inputs = 3nlog(n)
# test set size=400


plt.plot(np.load('../data/divide_conquer/snrs.npy')[:-1], np.load('../data/divide_conquer/snr_acc_binary.npy')[:-1], '--bo', label='1024')
plt.plot(np.load('../data/divide_conquer/snrs_8192.npy'), np.load('../data/divide_conquer/snr_acc_binary_8192.npy'), '--ro', label='8192')
plt.plot(np.load('../data/divide_conquer/snrs_16384.npy')[:-1], np.load('../data/divide_conquer/snr_acc_binary_16384.npy')[:-1], '--go', label='16384')

plt.xlabel('snr db', fontsize=18)
plt.ylabel('binary detection accuracy', fontsize=14)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# frequency detection accuracy for diff total number of frequencies
# layers=6, inputs = 3nlog(n)
# test set size=400

plt.plot(np.load('../data/divide_conquer/snrs_1024t2.npy')[:-1], np.load('../data/divide_conquer/snr_acc_frequency_1024t2.npy')[:-1], '--bo', label='1024')
plt.plot(np.load('../data/divide_conquer/snrs_8192.npy'), np.load('../data/divide_conquer/snr_acc_frequency_8192.npy'), '--ro', label='8192')
plt.plot(np.load('../data/divide_conquer/snrs_16384.npy')[:-1], np.load('../data/divide_conquer/snr_acc_frequency_16384.npy')[:-1], '--go', label='16384')
plt.plot(np.load('../data/freq_detect/snrs.npy'), np.load('../data/freq_detect/mle_random.npy'), '--yo', label='mle random 300 samples')

plt.xlabel('snr db', fontsize=18)
plt.ylabel('frequency detection accuracy', fontsize=14)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# comparing random shifting vs no shifting 
# layers=6, inputs = 3nlog(n), possible=1024
# test set size=400


plt.plot(np.load('../data/divide_conquer/snrs_1024shift.npy'), np.load('../data/divide_conquer/snr_acc_binary_1024shift.npy'), '--bo', label='shifted: binary')
plt.plot(np.load('../data/divide_conquer/snrs_1024shift.npy'), np.load('../data/divide_conquer/snr_acc_frequency_1024shift.npy'), 'b', label='shifted: frequency')

plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_binary.npy'), '--ro', label='unshifted: binary')
plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_frequency.npy'), 'r', label='unshifted: frequency')

plt.xlabel('snr db', fontsize=18)
plt.ylabel('frequency detection accuracy', fontsize=14)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# comparing logn vs 3logn inputs
# layers=6, inputs = 3log(n), possible=1024
# test set size=400

plt.plot(np.load('../data/divide_conquer/snrs_1024.npy'), np.load('../data/divide_conquer/snr_acc_binary_1024.npy'), '--bo', label='log(n): binary')
plt.plot(np.load('../data/divide_conquer/snrs_1024.npy'), np.load('../data/divide_conquer/snr_acc_frequency_1024.npy'), 'b', label='log(n): frequency')

plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_binary.npy'), '--ro', label='3log(n): binary')
plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_frequency.npy'), 'r', label='3log(n): frequency')

plt.xlabel('snr db', fontsize=18)
plt.ylabel('frequency detection accuracy', fontsize=14)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# comparing testing on all frequencies vs none within pi/8 of 0, pi
# layers=6, inputs = 3nlog(n), possible=1024
# test set size=400

plt.plot(np.load('../data/divide_conquer/snrs_1024noboundary.npy'), np.load('../data/divide_conquer/snr_acc_binary_1024noboundary.npy'), '--bo', label='no boundary: binary')
plt.plot(np.load('../data/divide_conquer/snrs_1024noboundary.npy'), np.load('../data/divide_conquer/snr_acc_frequency_1024noboundary.npy'), 'b', label='no boundary: frequency')

plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_binary.npy'), '--ro', label='all: binary')
plt.plot(np.load('../data/divide_conquer/snrs.npy'), np.load('../data/divide_conquer/snr_acc_frequency.npy'), 'r', label='all: frequency')

plt.xlabel('snr db', fontsize=18)
plt.ylabel('frequency detection accuracy', fontsize=14)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()
